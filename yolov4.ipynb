# %% [markdown]
# <a href="https://colab.research.google.com/github/red-hai/-/blob/main/yolov4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/red-hai/yolov4-tf2.git
# Out:
# Cloning into 'yolov4-tf2'...
# remote: Enumerating objects: 203, done.
# remote: Total 203 (delta 0), reused 0 (delta 0), pack-reused 203
# Receiving objects: 100% (203/203), 5.35 MiB | 12.43 MiB/s, done.
# Resolving deltas: 100% (102/102), done.

# %%
cd /content/drive/Shareddrives/204880354@qq.com/yolov4_tf/yolov4-tf2

# %%
# !python /content/drive/Shareddrives/204880354@qq.com/yolov4_tf/yolov4-tf2/VOCdevkit/VOC2007/voc2yolo4.py
# Out:
# train and val size 1082
# traub suze 1082

# %%
cd /content/drive/Shareddrives/204880354@qq.com/yolov4_tf/yolov4-tf2/
# Out:
# /content/drive/Shareddrives/204880354@qq.com/yolov4_tf/yolov4-tf2

# %%
cd ../

# %%
# !python /content/drive/Shareddrives/204880354@qq.com/yolov4_tf/yolov4-tf2/voc_annotation.py

# %%
# !cp -r /content/yolov4-tf2 /content/drive/Shareddrives/204880354@qq.com/yolov4_tf/

# %%
# !python train.py
# Out:
# Create YOLOv4 model with 9 anchors and 1 classes.
# Load weights model_data/yolo4_voc_weight.h5.
# WARNING:tensorflow:Skipping loading weights for layer #367 (named conv2d_109) due to mismatch in shape for weight conv2d_109/kernel:0. Weight expects shape (1, 1, 1024, 18). Received saved weight with shape (75, 1024, 1, 1)
# WARNING:tensorflow:Skipping loading weights for layer #367 (named conv2d_109) due to mismatch in shape for weight conv2d_109/bias:0. Weight expects shape (18,). Received saved weight with shape (75,)
# WARNING:tensorflow:Skipping loading weights for layer #368 (named conv2d_101) due to mismatch in shape for weight conv2d_101/kernel:0. Weight expects shape (1, 1, 512, 18). Received saved weight with shape (75, 512, 1, 1)
# WARNING:tensorflow:Skipping loading weights for layer #368 (named conv2d_101) due to mismatch in shape for weight conv2d_101/bias:0. Weight expects shape (18,). Received saved weight with shape (75,)
# ...

# %%
# !python predict.py
# Out:
# WARNING:tensorflow:From /content/drive/Shareddrives/204880354@qq.com/yolov4_tf/yolov4-tf2/yolo.py:48: The name tf.keras.backend.get_session is deprecated. Please use tf.compat.v1.keras.backend.get_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/layers/normalization/batch_normalization.py:532: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# logstrained_weights_stage_1.h5 model, anchors, and classes loaded.
# Input image filename:img/street.jpg
# Found 6 boxes for img
# b'person 1.00'
# b'person 1.00'
# b'person 1.00'
# b'person 0.99'
# b'person 0.96'
# b'person 0.74'
# 5.131669862999843
# Input image filename:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive.flush_and_unmount()
# Out:
# Drive not mounted, so nothing to flush and unmount.

# %%
# !wget https://a.vij7.top/s/EQaGgu3
# Out:
# --2022-01-16 04:57:56--  https://a.vij7.top/s/EQaGgu3
# Resolving a.vij7.top (a.vij7.top)... 211.152.148.44, 211.152.148.77, 211.152.149.16, ...
# Connecting to a.vij7.top (a.vij7.top)|211.152.148.44|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://xmyp22-my.sharepoint.cn/:u:/g/personal/admin_xmyp22_partner_onmschina_cn/ET6AEb0rkjhOjL7RvjMTg2kB3FH2H8kT0MywK0MFUWZv3A?download=1 [following]
# --2022-01-16 04:57:57--  https://xmyp22-my.sharepoint.cn/:u:/g/personal/admin_xmyp22_partner_onmschina_cn/ET6AEb0rkjhOjL7RvjMTg2kB3FH2H8kT0MywK0MFUWZv3A?download=1
# Resolving xmyp22-my.sharepoint.cn (xmyp22-my.sharepoint.cn)... 40.73.129.53, 2406:e500:4600:1::53
# Connecting to xmyp22-my.sharepoint.cn (xmyp22-my.sharepoint.cn)|40.73.129.53|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /personal/admin_xmyp22_partner_onmschina_cn/Documents/2022/1/16/cf893813-34d7-4ef0-aa12-2dd46bd593ac/yolo4_voc_weight.h5 [following]
# ...
